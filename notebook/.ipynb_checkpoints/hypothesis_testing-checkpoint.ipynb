# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # for EDA plots
import seaborn as sns # for EDA plots
from scipy import stats # for Shapiro-Wilks test, ttest_ind
from sklearn.model_selection import train_test_split # for splitting dataframes into train & test samples

# %%
# Read in the 2 DFs from CSV file
df_clean = pd.read_csv('data/df_clean.csv')
df_impute = pd.read_csv('data/df_impute.csv')

# %% [markdown]
# # Summary of Hypothesis Tests We Will Run:
#
# t-tests (binary categorical values):
#
# 1) Are average X different between "Has metabolic syndrome" and "Does not have metabolic syndrome"?
# 2) Are average X different between Male/Female?
#
# ... where X = BMI, WaistCirc, Albuminuria, UrAlbCr, UricAcid, BloodGlucose, HDL, Triglycerides, Income, Age.
#
# One-way ANOVA (multi-category values):
#
# 3) Are average X different between difference Races?
#
# ... where X = BMI, WaistCirc, Albuminuria, UrAlbCr, UricAcid, BloodGlucose, HDL, Triglycerides, Income, Age <font color="red">AND METABOLIC SYNDROME</font> (even though this is a binary variable, let's see what the ANOVA turns up from using this as a mean, which translates to proportion of people with Metabolic Syndrome).

# %%
# Remind of the columns names, again?
df_impute.columns
# Out:
# Index(['Unnamed: 0', 'seqn', 'Age', 'Sex', 'Marital', 'Income', 'Race',
#        'WaistCirc', 'BMI', 'Albuminuria', 'UrAlbCr', 'UricAcid',
#        'BloodGlucose', 'HDL', 'Triglycerides', 'MetabolicSyndrome'],
#       dtype='object')

# %%
# What are the unique categorical variables for Sex, Marital, Race, MetabolicSyndrome?
print (f"\nCategories for column: Sex:\n{df_impute['Sex'].unique()}")
print (f"\nCategories for column: Race:\n{df_impute['Race'].unique()}")
print (f"\nCategories for column: Marital:\n{df_impute['Marital'].unique()}")
print (f"\nCategories for column: MetabolicSyndrome:\n{df_impute['MetabolicSyndrome'].unique()}")
# Out:
# Categories for column: Sex:
# ['Male' 'Female']
#
# Categories for column: Race:
# ['White' 'Asian' 'Black' 'MexAmerican' 'Hispanic' 'Other']
#
# Categories for column: Marital:
# ['Single' 'Married' 'Widowed' 'Divorced' 'Separated']
#
# Categories for column: MetabolicSyndrome:
# [0 1]

# %% [markdown]
# # Hypothesis Tests for "Has MetabolicSyndrome" vs. "Doesn't Have MetabolicSyndrome"
#
# 2 steps:
# 1. Levene's test for equal variance, which informs the equal_var parameter for the stats.ttest_ind()
# 2. t-test via stats.ttest_ind()

# %%
# Define a list with the dimensions we want to examine in each Hypothesis Test
dimensions = ['WaistCirc', 'BMI', 'Albuminuria', 'UrAlbCr', 'UricAcid', 'BloodGlucose', 'HDL', 'Triglycerides', 'Income', 'Age']

# %%
# Show barplot of Dimension Means on 'Metabolic Syndrome' categories:
for dimension in dimensions:
    sns.barplot(data=df_impute, x='MetabolicSyndrome', y=dimension)
    plt.show()

# %%
# First Use Levene's test to verify equal variance between 2 groups on dimensions:
# 'WaistCirc', 'BMI','Albuminuria', 'UrAlbCr', 'UricAcid', 'BloodGlucose', 'HDL', 'Triglycerides'

# Define the masks
has_ms_mask = df_impute['MetabolicSyndrome'] == 1
no_ms_mask = df_impute['MetabolicSyndrome'] == 0

# Store the Levenes test results
levenes_results = []

# Store the mean for each dimension in each group
means = []

for dimension in dimensions:
    # Get the Series for Dimension in each Group
    dimension_has_ms = df_impute[has_ms_mask][dimension]
    dimension_no_ms  = df_impute[no_ms_mask][dimension]

    # Calculate the mean for each Dimension/Group
    means.append(dict({'dimension_name':dimension, 'has_ms':dimension_has_ms.mean(), 'no_ms':dimension_no_ms.mean()}))

    # Calculate and store Levene stats
    stat, p = stats.levene(dimension_has_ms, dimension_no_ms)
    levenes_results.append(dict({'dimension_name' : dimension, 'stat' : stat, 'p': p}))
    print (f"Levene test result for {dimension}: p = {p}, Result: Variances are {'**NOT** ' if round(p, 2) < 0.05 else ''}equal")
# Out:
# Levene test result for WaistCirc: p = 0.17439731450012333, Result: Variances are equal
# Levene test result for BMI: p = 3.744839622941711e-05, Result: Variances are **NOT** equal
# Levene test result for Albuminuria: p = 4.017997154140853e-13, Result: Variances are **NOT** equal
# Levene test result for UrAlbCr: p = 0.00011067393676236355, Result: Variances are **NOT** equal
# Levene test result for UricAcid: p = 0.0022105965941049094, Result: Variances are **NOT** equal
# Levene test result for BloodGlucose: p = 1.668406034475705e-23, Result: Variances are **NOT** equal
# Levene test result for HDL: p = 1.2286233173573101e-08, Result: Variances are **NOT** equal
# Levene test result for Triglycerides: p = 2.658370873768701e-45, Result: Variances are **NOT** equal
# Levene test result for Income: p = 0.0001028018000662395, Result: Variances are **NOT** equal
# Levene test result for Age: p = 1.1212000511282527e-06, Result: Variances are **NOT** equal

# %% [markdown]
# #### Levene's test when comparing dimensions split by 'MetabolicSyndrome' (Has It vs. Does not Have It) indicates the following:
#
# Variances are equal for the 2 groups (has_ms, no_ms) for these following dimensions, and we can use standard t-test:
# 1. WaistCirc
#
# Variances are NOT equal for the 2 groups (has_ms, no_ms) for these following dimensions, and we need to use Welch's t-test (pass 'False' for equal_var in stats.ttest):
# 1. BMI
# 2. Albuminuria
# 3. UrAlbCr
# 4. UricAcid
# 5. BloodGlucose
# 6. HDL
# 7. Triglycerides
# 8. Income
# 9. Age

# %%
# Do t-tests for all dimensions!

t_results = []

for dict_entry in levenes_results:
    dimension = dict_entry['dimension_name']
    dimension_p = dict_entry['p']
    equal_var_param = False # Default (most of our dimensions are not equal variance)
    if dimension_p > 0.05:
        # Set 'equal_var_param' set to 'True' (meaning, 2 datasets ARE equal variance)
        #print (f"Note: Equal variances for dimension {dimension}")  # Check and confirm!
        equal_var_param = True

    # Run the t-test and store the results
    stat, p = stats.ttest_ind(df_impute[has_ms_mask][dimension], df_impute[no_ms_mask][dimension], equal_var=equal_var_param)
    t_results.append(dict({'dimension_name' : dimension, 'equal_var_param' : equal_var_param, 'stat' : stat, 'p' : p}))

# %%
# Gut-check that t_results is what we want; we will print out something more readable in a below cell
t_results
# Out:
# [{'dimension_name': 'WaistCirc',
#   'equal_var_param': True,
#   'stat': 26.165407054357438,
#   'p': 1.5462850516600822e-131},
#  {'dimension_name': 'BMI',
#   'equal_var_param': False,
#   'stat': 20.881735567073623,
#   'p': 5.7439237164190525e-84},
#  {'dimension_name': 'Albuminuria',
#   'equal_var_param': False,
#   'stat': 6.523071363860894,
#   'p': 1.0323227968063208e-10},
#  {'dimension_name': 'UrAlbCr',
#   'equal_var_param': False,
#   'stat': 3.381374389078004,
#   'p': 0.0007485165882493893},
#  {'dimension_name': 'UricAcid',
#   'equal_var_param': False,
#   'stat': 11.853609110639535,
#   'p': 6.035533456367002e-31},
#  {'dimension_name': 'BloodGlucose',
#   'equal_var_param': False,
#   'stat': 15.147307212572214,
#   'p': 9.117590017521449e-47},
#  {'dimension_name': 'HDL',
#   'equal_var_param': False,
#   'stat': -19.91855435350617,
#   'p': 3.2667959101286097e-80},
#  {'dimension_name': 'Triglycerides',
#   'equal_var_param': False,
#   'stat': 18.310620932503344,
#   'p': 6.414711048677813e-64},
#  {'dimension_name': 'Income',
#   'equal_var_param': False,
#   'stat': -4.5724006526804555,
#   'p': 5.179514196564167e-06},
#  {'dimension_name': 'Age',
#   'equal_var_param': False,
#   'stat': 12.706935808727012,
#   'p': 1.9980401489780906e-35}]

# %%
# Print out the means of each Dimension:

for entry in means:
    print (f"Dimension: {entry['dimension_name']}:  Means [has_ms, no_ms]: [{entry['has_ms']}, {entry['no_ms']}]")
# Out:
# Dimension: WaistCirc:  Means [has_ms, no_ms]: [109.05749999999999, 92.64360587002096]
# Dimension: BMI:  Means [has_ms, no_ms]: [32.547236842105264, 26.6135569531796]
# Dimension: Albuminuria:  Means [has_ms, no_ms]: [0.25263157894736843, 0.11250873515024458]
# Dimension: UrAlbCr:  Means [has_ms, no_ms]: [77.4975, 29.656079664570235]
# Dimension: UricAcid:  Means [has_ms, no_ms]: [6.014868421052632, 5.242627533193571]
# Dimension: BloodGlucose:  Means [has_ms, no_ms]: [125.47631578947369, 99.50803633822501]
# Dimension: HDL:  Means [has_ms, no_ms]: [45.94210526315789, 57.6932215234102]
# Dimension: Triglycerides:  Means [has_ms, no_ms]: [180.78157894736842, 98.40041928721175]
# Dimension: Income:  Means [has_ms, no_ms]: [3712.6973684210525, 4298.777078965758]
# Dimension: Age:  Means [has_ms, no_ms]: [55.90526315789474, 46.552760307477286]

# %%
# Print out the results of the t-tests for 'MetabolicSyndrome' groups [0,1]

print (f"t-test results for dimensions grouped by has metabolic syndrome vs. does not have metabolic syndrome:")

significantly_different_list = ''
not_significantly_different_list = ''

for result in t_results:
    if result['p'] < 0.05:
        significantly_different_list += result['dimension_name'] + ', '
    else:
        not_significantly_different_list += result['dimension_name'] + ', '

# Get rid of last ','
significantly_different_list = significantly_different_list[:-2]
not_significantly_different_list = not_significantly_different_list[:-2]

print (f"\nSignificantly Different Means:\n\t{significantly_different_list}")
print (f"\nNOT Significantly Different Means:\n\t{not_significantly_different_list}")
# Out:
# t-test results for dimensions grouped by has metabolic syndrome vs. does not have metabolic syndrome:
#
# Significantly Different Means:
# 	WaistCirc, BMI, Albuminuria, UrAlbCr, UricAcid, BloodGlucose, HDL, Triglycerides, Income, Age
#
# NOT Significantly Different Means:

# %% [markdown]
# ### Results for Group Means for "Has Metabolic Syndrome" vs. "Does Not Have Metabolic Syndrome" Dimensions:
#
# For all Dimensions, the **means are statistically different** for those who "have metabolic syndrome" vs. those who "do not have metabolic syndrome".
#
# Dimensions are:
# * WaistCirc
# * BMI
# * Albuminuria
# * UrAlbCr
# * UricAcid
# * BloodGlucose
# * HDL
# * Triglycerides
# * Income
# * Age

# %% [markdown]
# # Hypothesis Tests for Male vs. Female
#
# 2 steps:
# 1. Levene's test for equal variance, which informs the equal_var parameter for the stats.ttest_ind()
# 2. t-test via stats.ttest_ind()

# %%
# Show barplot of Dimension Means on 'Sex' categories:
for dimension in dimensions:
    sns.barplot(data=df_impute, x='Sex', y=dimension)
    plt.show()

# %%
# First Use Levene's test to verify equal variance between 2 groups on dimensions:
# 'WaistCirc', 'BMI','Albuminuria', 'UrAlbCr', 'UricAcid', 'BloodGlucose', 'HDL', 'Triglycerides'

# Define the masks
male_mask = df_impute['Sex'] == 'Male'
female_mask = df_impute['Sex'] == 'Female'

# Store the Levenes test results
levenes_results = []

# Store the mean for each dimension in each group
means = []

for dimension in dimensions:
    # Get the Series for Dimension in each Group
    dimension_male = df_impute[male_mask][dimension]
    dimension_female  = df_impute[female_mask][dimension]

    # Calculate the mean for each Dimension/Group
    means.append(dict({'dimension_name':dimension, 'male':dimension_male.mean(), 'female':dimension_female.mean()}))

    # Calculate and store Levene stats
    stat, p = stats.levene(dimension_male, dimension_female)
    levenes_results.append(dict({'dimension_name' : dimension, 'stat' : stat, 'p': p}))
    print (f"Levene test result for {dimension}: p = {p}, Result: Variances are {'**NOT** ' if round(p, 2) < 0.05 else ''}equal")
# Out:
# Levene test result for WaistCirc: p = 0.04287396722188298, Result: Variances are **NOT** equal
# Levene test result for BMI: p = 1.609008523380027e-10, Result: Variances are **NOT** equal
# Levene test result for Albuminuria: p = 0.22386664790950342, Result: Variances are equal
# Levene test result for UrAlbCr: p = 0.4273973525034417, Result: Variances are equal
# Levene test result for UricAcid: p = 0.2538844477285095, Result: Variances are equal
# Levene test result for BloodGlucose: p = 0.20513798064969188, Result: Variances are equal
# Levene test result for HDL: p = 3.909074307832056e-07, Result: Variances are **NOT** equal
# Levene test result for Triglycerides: p = 3.982262659993102e-07, Result: Variances are **NOT** equal
# Levene test result for Income: p = 0.6795671996474376, Result: Variances are equal
# Levene test result for Age: p = 0.5255884801597286, Result: Variances are equal

# %% [markdown]
# #### Levene's test when comparing dimensions split by 'Sex' (Male vs. Female) indicates the following:
#
# Variances are equal for the 2 groups (has_ms, no_ms) for these following dimensions, and we can use standard t-test:
# 1. Albuminuria
# 2. UrAlbCr
# 3. UricAcid
# 4. BloodGlucose
# 5. Income
# 6. Age
#
# Variances are NOT equal for the 2 groups (has_ms, no_ms) for these following dimensions, and we need to use Welch's t-test (pass 'False' for equal_var in stats.ttest):
# 1. BMI
# 2. HDL
# 3. Triglycerides

# %%
# Do t-tests for all dimensions!

t_results = []

for dict_entry in levenes_results:
    dimension = dict_entry['dimension_name']
    dimension_p = dict_entry['p']
    equal_var_param = False # Default (most of our dimensions are not equal variance)
    if dimension_p > 0.05:
        # Set 'equal_var_param' set to 'True' (meaning, 2 datasets ARE equal variance)
        #print (f"Note: Equal variances for dimension {dimension}")  # Check and confirm!
        equal_var_param = True

    # Run the t-test and store the results
    stat, p = stats.ttest_ind(df_impute[male_mask][dimension], df_impute[female_mask][dimension], equal_var=equal_var_param)
    t_results.append(dict({'dimension_name' : dimension, 'equal_var_param' : equal_var_param, 'stat' : stat, 'p' : p}))

# %%
# Print out the means of each Dimension:

for entry in means:
    print (f"Dimension: {entry['dimension_name']}:  Means [male, female]: [{entry['male']}, {entry['female']}]")
# Out:
# Dimension: WaistCirc:  Means [male, female]: [100.39754174397032, 96.3415543575921]
# Dimension: BMI:  Means [male, female]: [28.356447124304268, 28.97722371967655]
# Dimension: Albuminuria:  Means [male, female]: [0.1725417439703154, 0.1500449236298293]
# Dimension: UrAlbCr:  Means [male, female]: [50.157949907235626, 42.46691823899372]
# Dimension: UricAcid:  Means [male, female]: [6.085807050092765, 4.953279424977538]
# Dimension: BloodGlucose:  Means [male, female]: [111.66790352504638, 105.46271338724169]
# Dimension: HDL:  Means [male, female]: [48.529684601113175, 58.544474393531]
# Dimension: Triglycerides:  Means [male, female]: [139.3126159554731, 115.02785265049415]
# Dimension: Income:  Means [male, female]: [4209.601113172542, 3984.950584007188]
# Dimension: Age:  Means [male, female]: [50.026901669758814, 49.57412398921833]

# %%
# Print out the results of the t-tests for 'Sex' groups ['Male', 'Female]

print (f"t-test results for dimensions grouped by Sex (i.e. Male vs. Female):")

significantly_different_list = ''
not_significantly_different_list = ''

for result in t_results:
    if result['p'] < 0.05:
        significantly_different_list += result['dimension_name'] + ', '
    else:
        not_significantly_different_list += result['dimension_name'] + ', '

# Get rid of last ','
significantly_different_list = significantly_different_list[:-2]
not_significantly_different_list = not_significantly_different_list[:-2]

print (f"\nSignificantly Different Means:\n\t{significantly_different_list}")
print (f"\nNOT Significantly Different Means:\n\t{not_significantly_different_list}")
# Out:
# t-test results for dimensions grouped by Sex (i.e. Male vs. Female):
#
# Significantly Different Means:
# 	WaistCirc, BMI, UricAcid, BloodGlucose, HDL, Triglycerides
#
# NOT Significantly Different Means:
# 	Albuminuria, UrAlbCr, Income, Age

# %% [markdown]
# ### Results for Group Means for Male vs. Female Dimensions:
#
# For the following Dimensions, the **means are statistically different** for Males vs. Females:
#
# Dimensions are:
# * WaistCirc
# * BMI
# * UricAcid
# * BloodGlucose
# * HDL
# * Triglycerides
#
# For the following Dimensions, there is **no statistical difference between means** for Males vs. Females:
# * Albuminuria
# * UrAlbCr
# * Income
# * Age

# %% [markdown]
# # Hypothesis Tests for Race: ['White' 'Asian' 'Black' 'MexAmerican' 'Hispanic' 'Other']
#
# Steps:
# 1. Add "MetabolicSyndrome" to the Dimensions being checked across Races (this is a binary value, but the mean of this will be an indicator of % of sample in each Race, with Metabolic Syndrome)
# 2. Check Normality (Shapiro Wilks) for each Race group for each Dimension
# 3. Check for Homoscedasicity (Levenes) for each Race group for each Dimension
# 4. Perform One-way ANOVA (stats.f_oneway())
#
#
# NOTE:  One-way ANOVA assumes that:
# 1. the data is normal
# 2. the variances of the groups are approximately equal
#
# According to https://statistics.laerd.com/statistical-guides/one-way-anova-statistical-guide-3.php:
# a) one-way ANOVA "tolerates violations to its normality assumption rather well"
#
# According to https://www.quality-control-plan.com/StatGuide/oneway_anova_ass_viol.htm:
# b) if variances aren't equal, effect mitigated when sample sizes are equal
#
#
# There is a greater likelihood of Type I errors if ANOVA is used with data that don't have equal variances and sample sizes aren't equal (which they do not, from data below).
#
# However, due to the following considerations, I will accept the potential for increased Type I errors in this situation:
# 1) This is an analysis only, where:
# - We will be building a logistic regression model wherein the OR and other statistical measures of validity will be examined
# - The analysis here is to add to EDA and inform hypothesis generation primarily, and is not of its own primary importance

# %%
# Update the definition of "dimensions" from the above 2 tests, to include MetabolicSyndrome
dimensions = ['WaistCirc', 'BMI', 'Albuminuria', 'UrAlbCr', 'UricAcid', 'BloodGlucose', 'HDL', 'Triglycerides', 'Income', 'Age', 'MetabolicSyndrome']

# %%
# Show barplot of Dimension Means on 'Marital' categories:
for dimension in dimensions:
    sns.barplot(data=df_impute, x='Race', y=dimension)
    plt.show()

# %%
# Gut-check barplot means value shown in first graph
df_impute[df_impute['Race']=='Asian']['BMI'].mean()
# Out:
# 24.3542899408284

# %%
# Define masks for each Race
# categories = ['White', 'Asian', 'Black', 'MexAmerican', 'Hispanic', 'Other']

white_mask = df_impute['Race']=='White'
asian_mask = df_impute['Race']=='Asian'
black_mask = df_impute['Race']=='Black'
mexamerican_mask = df_impute['Race']=='MexAmerican'
hispanic_mask = df_impute['Race']=='Hispanic'
other_mask = df_impute['Race']=='Other'

# Define ANOVA results
anova_results = []

# Define means storage
means = []

# Define sample size storage
sample_sizes = []

# Define Series for each Dimension
for dimension in dimensions:
    # Get the Series for Dimension in each Group
    dimension_white  = df_impute[white_mask][dimension]
    dimension_asian  = df_impute[asian_mask][dimension]
    dimension_black  = df_impute[black_mask][dimension]
    dimension_mexamerican  = df_impute[mexamerican_mask][dimension]
    dimension_hispanic  = df_impute[hispanic_mask][dimension]
    dimension_other  = df_impute[other_mask][dimension]

    # Calculate the mean for each Dimension/Group
    means.append(dict({'dimension_name':dimension, 'white':dimension_white.mean(), 'asian':dimension_asian.mean(), 'black':dimension_black.mean(), 'mexamerican':dimension_mexamerican.mean(), 'hispanic':dimension_hispanic.mean(), 'other':dimension_other.mean()}))

    # Calculate sample size for each Dimension/Group
    sample_sizes.append(dict({'dimension_name':dimension, 'white':dimension_white.count(), 'asian':dimension_asian.count(), 'black':dimension_black.count(), 'mexamerican':dimension_mexamerican.count(), 'hispanic':dimension_hispanic.count(), 'other':dimension_other.count()}))

    # Calculate, store and print Levene stats
    stat, p = stats.levene(dimension_white, dimension_asian, dimension_black, dimension_mexamerican, dimension_hispanic, dimension_other)
    levenes_results.append(dict({'dimension_name' : dimension, 'stat' : stat, 'p': p}))
    print (f"Levene test result for {dimension}: p = {p}, Result: Variances are {'**NOT** ' if round(p, 2) < 0.05 else ''}equal")

    # Calculate, store and print ANOVA stats
    stat, p = stats.f_oneway(dimension_white, dimension_asian, dimension_black, dimension_mexamerican, dimension_hispanic, dimension_other)
    anova_results.append(dict({'dimension_name' : dimension, 'stat' : stat, 'p': p}))
    print (f"ANOVA test result for {dimension}: p = {p}, Result: {'At least one of the' if round(p, 2) < 0.05 else 'NO'} means are different")

    print()
# Out:
# Levene test result for WaistCirc: p = 1.127157055096749e-05, Result: Variances are **NOT** equal
# ANOVA test result for WaistCirc: p = 1.2664899308101302e-41, Result: At least one of the means are different
#
# Levene test result for BMI: p = 4.972066326842892e-11, Result: Variances are **NOT** equal
# ANOVA test result for BMI: p = 1.6087757628112e-41, Result: At least one of the means are different
#
# Levene test result for Albuminuria: p = 0.04978846166002772, Result: Variances are equal
# ANOVA test result for Albuminuria: p = 0.04978846166002772, Result: NO means are different
#
# Levene test result for UrAlbCr: p = 0.027990768582377135, Result: Variances are **NOT** equal
# ANOVA test result for UrAlbCr: p = 0.03037828402588226, Result: At least one of the means are different
#
# Levene test result for UricAcid: p = 0.3880789351569232, Result: Variances are equal
# ANOVA test result for UricAcid: p = 0.0036045035249721133, Result: At least one of the means are different
#
# Levene test result for BloodGlucose: p = 0.0023265475616893153, Result: Variances are **NOT** equal
# ANOVA test result for BloodGlucose: p = 0.0053576190316102406, Result: At least one of the means are different
#
# Levene test result for HDL: p = 0.00020666333828499184, Result: Variances are **NOT** equal
# ANOVA test result for HDL: p = 1.5909934535479864e-07, Result: At least one of the means are different
#
# Levene test result for Triglycerides: p = 0.0003943841730785901, Result: Variances are **NOT** equal
# ANOVA test result for Triglycerides: p = 2.998200847895345e-13, Result: At least one of the means are different
#
# Levene test result for Income: p = 8.781919138243833e-09, Result: Variances are **NOT** equal
# ANOVA test result for Income: p = 3.619196714420278e-12, Result: At least one of the means are different
#
# Levene test result for Age: p = 0.0007904005778853086, Result: Variances are **NOT** equal
# ANOVA test result for Age: p = 2.7396274830949586e-09, Result: At least one of the means are different
#
# Levene test result for MetabolicSyndrome: p = 1.380082159901747e-05, Result: Variances are **NOT** equal
# ANOVA test result for MetabolicSyndrome: p = 1.380082159901747e-05, Result: At least one of the means are different

# %%
# Print out the means of each Dimension:

for entry in means:
    print (f"Dimension: {entry['dimension_name']}:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [{entry['white']}, {entry['asian']}, {entry['black']}, {entry['mexamerican']}, {entry['hispanic']}, {entry['other']}]")
# Out:
# Dimension: WaistCirc:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [100.66622093023257, 87.35650887573965, 100.555905511811, 100.80143540669856, 99.0365470852018, 96.64528301886791]
# Dimension: BMI:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [28.856744186046512, 24.3542899408284, 30.510925196850398, 29.998564593301435, 29.048878923766814, 28.758490566037732]
# Dimension: Albuminuria:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [0.13953488372093023, 0.12130177514792899, 0.1968503937007874, 0.20095693779904306, 0.17488789237668162, 0.20754716981132076]
# Dimension: UrAlbCr:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [32.81323255813953, 30.045059171597632, 76.25673228346456, 72.29334928229666, 35.196143497757845, 23.86547169811321]
# Dimension: UricAcid:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [5.601162790697674, 5.4402366863905325, 5.59763779527559, 5.205263157894738, 5.390134529147982, 5.362264150943396]
# Dimension: BloodGlucose:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [106.68255813953489, 105.01479289940828, 110.86023622047244, 115.1244019138756, 108.56053811659193, 111.86792452830188]
# Dimension: HDL:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [52.98837209302326, 54.47041420118343, 56.61220472440945, 50.58373205741627, 50.62331838565022, 54.22641509433962]
# Dimension: Triglycerides:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [137.79767441860466, 127.98224852071006, 100.65551181102362, 145.2775119617225, 129.92376681614348, 112.67924528301887]
# Dimension: Income:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [4302.325581395349, 4929.881656804734, 3845.5708661417325, 3438.995215311005, 3370.403587443946, 3452.830188679245]
# Dimension: Age:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [52.13488372093023, 45.642011834319526, 49.403543307086615, 46.68421052631579, 52.00896860986547, 45.094339622641506]
# Dimension: MetabolicSyndrome:  Means [White, Asian, Black, Mexamerican, Hispanic, Other]: [0.3686046511627907, 0.23668639053254437, 0.33267716535433073, 0.41626794258373206, 0.4125560538116592, 0.2830188679245283]

# %%
# Print out the sample sizes of each Dimension:

for entry in sample_sizes:
    print (f"Dimension: {entry['dimension_name']}:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [{entry['white']}, {entry['asian']}, {entry['black']}, {entry['mexamerican']}, {entry['hispanic']}, {entry['other']}]")
# Out:
# Dimension: WaistCirc:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: BMI:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: Albuminuria:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: UrAlbCr:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: UricAcid:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: BloodGlucose:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: HDL:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: Triglycerides:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: Income:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: Age:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]
# Dimension: MetabolicSyndrome:  Sample Sizes [White, Asian, Black, Mexamerican, Hispanic, Other]: [860, 338, 508, 209, 223, 53]

# %%
# Do Shapiro Wilks test for all groups to test for "normality of residuals" per group given to ANOVA.  Print the results.

for dimension in dimensions:
    # Get the Series for Dimension in each Group
    dimension_white  = df_impute[white_mask][dimension]
    dimension_asian  = df_impute[asian_mask][dimension]
    dimension_black  = df_impute[black_mask][dimension]
    dimension_mexamerican  = df_impute[mexamerican_mask][dimension]
    dimension_hispanic  = df_impute[hispanic_mask][dimension]
    dimension_other  = df_impute[other_mask][dimension]

    races = {
        "white":dimension_white,
        "asian":dimension_asian,
        "black":dimension_black,
        "mexamerican":dimension_mexamerican,
        "hispanic":dimension_hispanic,
        "other":dimension_other
    }

    for key, race in races.items():
        stat, p = stats.shapiro(race)
        print (f"{dimension}: Shapiro-Wilks test p-value for Race {key}: {p}.  Data are{'' if round(p, 2) < 0.05 else ' **NOT**'} normally distributed.")

    print ()
# Out:
# WaistCirc: Shapiro-Wilks test p-value for Race white: 2.5430321737296424e-10.  Data are normally distributed.
# WaistCirc: Shapiro-Wilks test p-value for Race asian: 2.982383229266361e-10.  Data are normally distributed.
# WaistCirc: Shapiro-Wilks test p-value for Race black: 5.68750749607716e-07.  Data are normally distributed.
# WaistCirc: Shapiro-Wilks test p-value for Race mexamerican: 0.006663518492132425.  Data are normally distributed.
# WaistCirc: Shapiro-Wilks test p-value for Race hispanic: 0.0010455036535859108.  Data are normally distributed.
# WaistCirc: Shapiro-Wilks test p-value for Race other: 0.062001634389162064.  Data are **NOT** normally distributed.
#
# BMI: Shapiro-Wilks test p-value for Race white: 2.4350850583523898e-17.  Data are normally distributed.
# BMI: Shapiro-Wilks test p-value for Race asian: 1.0773456779467061e-12.  Data are normally distributed.
# BMI: Shapiro-Wilks test p-value for Race black: 1.7355464531883594e-14.  Data are normally distributed.
# BMI: Shapiro-Wilks test p-value for Race mexamerican: 0.0005803724052384496.  Data are normally distributed.
# BMI: Shapiro-Wilks test p-value for Race hispanic: 1.8534587070462294e-05.  Data are normally distributed.
# BMI: Shapiro-Wilks test p-value for Race other: 1.9014480130863376e-05.  Data are normally distributed.
#
# Albuminuria: Shapiro-Wilks test p-value for Race white: 0.0.  Data are normally distributed.
# Albuminuria: Shapiro-Wilks test p-value for Race asian: 7.408089560472861e-33.  Data are normally distributed.
# Albuminuria: Shapiro-Wilks test p-value for Race black: 1.522047075011487e-36.  Data are normally distributed.
# Albuminuria: Shapiro-Wilks test p-value for Race mexamerican: 5.48100211820913e-25.  Data are normally distributed.
# Albuminuria: Shapiro-Wilks test p-value for Race hispanic: 1.2589847957662093e-26.  Data are normally distributed.
# Albuminuria: Shapiro-Wilks test p-value for Race other: 3.4014052425340724e-12.  Data are normally distributed.
#
# UrAlbCr: Shapiro-Wilks test p-value for Race white: 0.0.  Data are normally distributed.
# UrAlbCr: Shapiro-Wilks test p-value for Race asian: 2.32158161259164e-36.  Data are normally distributed.
# UrAlbCr: Shapiro-Wilks test p-value for Race black: 1.6409205017243608e-42.  Data are normally distributed.
# UrAlbCr: Shapiro-Wilks test p-value for Race mexamerican: 5.314796876384124e-29.  Data are normally distributed.
# UrAlbCr: Shapiro-Wilks test p-value for Race hispanic: 1.228916999325916e-28.  Data are normally distributed.
# UrAlbCr: Shapiro-Wilks test p-value for Race other: 6.334808301837122e-14.  Data are normally distributed.
#
# UricAcid: Shapiro-Wilks test p-value for Race white: 1.7457555401279023e-08.  Data are normally distributed.
# UricAcid: Shapiro-Wilks test p-value for Race asian: 0.0013239060062915087.  Data are normally distributed.
# UricAcid: Shapiro-Wilks test p-value for Race black: 2.1206969904596917e-05.  Data are normally distributed.
# UricAcid: Shapiro-Wilks test p-value for Race mexamerican: 0.022145777940750122.  Data are normally distributed.
# UricAcid: Shapiro-Wilks test p-value for Race hispanic: 0.017640279605984688.  Data are normally distributed.
# UricAcid: Shapiro-Wilks test p-value for Race other: 0.15061932802200317.  Data are **NOT** normally distributed.
#
# BloodGlucose: Shapiro-Wilks test p-value for Race white: 1.6251699069853498e-40.  Data are normally distributed.
# BloodGlucose: Shapiro-Wilks test p-value for Race asian: 1.5207608145556178e-26.  Data are normally distributed.
# BloodGlucose: Shapiro-Wilks test p-value for Race black: 5.9985509636303155e-31.  Data are normally distributed.
# BloodGlucose: Shapiro-Wilks test p-value for Race mexamerican: 2.038986679400967e-21.  Data are normally distributed.
# BloodGlucose: Shapiro-Wilks test p-value for Race hispanic: 9.47255693156938e-22.  Data are normally distributed.
# BloodGlucose: Shapiro-Wilks test p-value for Race other: 5.812157352624858e-11.  Data are normally distributed.
#
# HDL: Shapiro-Wilks test p-value for Race white: 3.612578579380646e-15.  Data are normally distributed.
# HDL: Shapiro-Wilks test p-value for Race asian: 9.170912562694866e-07.  Data are normally distributed.
# HDL: Shapiro-Wilks test p-value for Race black: 1.106144163937433e-16.  Data are normally distributed.
# HDL: Shapiro-Wilks test p-value for Race mexamerican: 4.324069777794648e-06.  Data are normally distributed.
# HDL: Shapiro-Wilks test p-value for Race hispanic: 2.4212218008301534e-08.  Data are normally distributed.
# HDL: Shapiro-Wilks test p-value for Race other: 0.1312500238418579.  Data are **NOT** normally distributed.
#
# Triglycerides: Shapiro-Wilks test p-value for Race white: 4.813415831820397e-37.  Data are normally distributed.
# Triglycerides: Shapiro-Wilks test p-value for Race asian: 7.328634434699428e-21.  Data are normally distributed.
# Triglycerides: Shapiro-Wilks test p-value for Race black: 8.409019975086837e-27.  Data are normally distributed.
# Triglycerides: Shapiro-Wilks test p-value for Race mexamerican: 3.536697627558273e-20.  Data are normally distributed.
# Triglycerides: Shapiro-Wilks test p-value for Race hispanic: 4.195610944612686e-16.  Data are normally distributed.
# Triglycerides: Shapiro-Wilks test p-value for Race other: 5.388895374380809e-07.  Data are normally distributed.
#
# Income: Shapiro-Wilks test p-value for Race white: 9.4591533069354e-27.  Data are normally distributed.
# Income: Shapiro-Wilks test p-value for Race asian: 3.7706190454705373e-16.  Data are normally distributed.
# Income: Shapiro-Wilks test p-value for Race black: 8.409646404206862e-21.  Data are normally distributed.
# Income: Shapiro-Wilks test p-value for Race mexamerican: 1.669560214904997e-14.  Data are normally distributed.
# Income: Shapiro-Wilks test p-value for Race hispanic: 4.012920638146733e-12.  Data are normally distributed.
# Income: Shapiro-Wilks test p-value for Race other: 4.275973878975492e-06.  Data are normally distributed.
#
# Age: Shapiro-Wilks test p-value for Race white: 1.2540751263657219e-17.  Data are normally distributed.
# Age: Shapiro-Wilks test p-value for Race asian: 4.1469263578619575e-09.  Data are normally distributed.
# Age: Shapiro-Wilks test p-value for Race black: 2.771495255515788e-10.  Data are normally distributed.
# Age: Shapiro-Wilks test p-value for Race mexamerican: 0.00012228675768710673.  Data are normally distributed.
# Age: Shapiro-Wilks test p-value for Race hispanic: 2.1080608348711394e-05.  Data are normally distributed.
# Age: Shapiro-Wilks test p-value for Race other: 0.005281495396047831.  Data are normally distributed.
#
# MetabolicSyndrome: Shapiro-Wilks test p-value for Race white: 4.1275666656226784e-40.  Data are normally distributed.
# MetabolicSyndrome: Shapiro-Wilks test p-value for Race asian: 3.930313547838747e-29.  Data are normally distributed.
# MetabolicSyndrome: Shapiro-Wilks test p-value for Race black: 9.61624467823299e-33.  Data are normally distributed.
# MetabolicSyndrome: Shapiro-Wilks test p-value for Race mexamerican: 3.935821885858556e-21.  Data are normally distributed.
# MetabolicSyndrome: Shapiro-Wilks test p-value for Race hispanic: 7.967360342180735e-22.  Data are normally distributed.
# MetabolicSyndrome: Shapiro-Wilks test p-value for Race other: 2.682100548601074e-11.  Data are normally distributed.

# %%
# Run ANOVA again, dropping the "Other" category entirely
# It has a small sample size and 3 of its dimensions are not normally distributed

# Define ANOVA results
anova_results = []

# Print what this test is
print ("This is a 'what-if' re-run of Levene and ANOVA when removing the 'Other' race entirely, due to Shapiro-Wilks results above.\n\n")

# Define Series for each Dimension
for dimension in dimensions:
    # Get the Series for Dimension in each Group
    dimension_white  = df_impute[white_mask][dimension]
    dimension_asian  = df_impute[asian_mask][dimension]
    dimension_black  = df_impute[black_mask][dimension]
    dimension_mexamerican  = df_impute[mexamerican_mask][dimension]
    dimension_hispanic  = df_impute[hispanic_mask][dimension]
    #dimension_other  = df_impute[other_mask][dimension]

    # Calculate, store and print Levene stats
    stat, p = stats.levene(dimension_white, dimension_asian, dimension_black, dimension_mexamerican, dimension_hispanic)#, dimension_other)
    levenes_results.append(dict({'dimension_name' : dimension, 'stat' : stat, 'p': p}))
    print (f"Levene test result for {dimension}: p = {p}, Result: Variances are {'**NOT** ' if round(p, 2) < 0.05 else ''}equal")

    # Calculate, store and print ANOVA stats
    stat, p = stats.f_oneway(dimension_white, dimension_asian, dimension_black, dimension_mexamerican, dimension_hispanic)#, dimension_other)
    anova_results.append(dict({'dimension_name' : dimension, 'stat' : stat, 'p': p}))
    print (f"ANOVA test result for {dimension}: p = {p}, Result: {'At least one of the' if round(p, 2) < 0.05 else 'NO'} means are different")

    print()
# Out:
# This is a 'what-if' re-run of Levene and ANOVA when removing the 'Other' race entirely, due to Shapiro-Wilks results above.
#
#
# Levene test result for WaistCirc: p = 9.871744467662661e-06, Result: Variances are **NOT** equal
# ANOVA test result for WaistCirc: p = 1.2657559858127064e-42, Result: At least one of the means are different
#
# Levene test result for BMI: p = 1.8060919842605147e-11, Result: Variances are **NOT** equal
# ANOVA test result for BMI: p = 6.7459567623592106e-43, Result: At least one of the means are different
#
# Levene test result for Albuminuria: p = 0.03306556055276682, Result: Variances are **NOT** equal
# ANOVA test result for Albuminuria: p = 0.03306556055276682, Result: At least one of the means are different
#
# Levene test result for UrAlbCr: p = 0.018255002851810222, Result: Variances are **NOT** equal
# ANOVA test result for UrAlbCr: p = 0.019780693714885757, Result: At least one of the means are different
#
# Levene test result for UricAcid: p = 0.4083309945206771, Result: Variances are equal
# ANOVA test result for UricAcid: p = 0.002045445444974033, Result: At least one of the means are different
#
# Levene test result for BloodGlucose: p = 0.0009857321229918173, Result: Variances are **NOT** equal
# ANOVA test result for BloodGlucose: p = 0.0027771125860445844, Result: At least one of the means are different
#
# Levene test result for HDL: p = 0.0001383198155725997, Result: Variances are **NOT** equal
# ANOVA test result for HDL: p = 5.4086080127936814e-08, Result: At least one of the means are different
#
# Levene test result for Triglycerides: p = 0.00018582437558264432, Result: Variances are **NOT** equal
# ANOVA test result for Triglycerides: p = 1.7874652678822656e-13, Result: At least one of the means are different
#
# Levene test result for Income: p = 4.943132729619203e-09, Result: Variances are **NOT** equal
# ANOVA test result for Income: p = 3.198915178394749e-12, Result: At least one of the means are different
#
# Levene test result for Age: p = 0.0003842165520690381, Result: Variances are **NOT** equal
# ANOVA test result for Age: p = 4.378092686003347e-09, Result: At least one of the means are different
#
# Levene test result for MetabolicSyndrome: p = 7.440964610213899e-06, Result: Variances are **NOT** equal
# ANOVA test result for MetabolicSyndrome: p = 7.440964610213899e-06, Result: At least one of the means are different

# %% [markdown]
# ### Results for Group Means for different Races:
# (Using results for ALL Races, including "Other")
#
# For the Dimensions below, **at least one of the means are statistically different** amongst different Races: White, Asian, Black, Mexamerican, Hispanic, Other.
#
# Dimensions are:
# * WaistCirc
# * BMI
# * UrAlbCr
# * UricAcid
# * BloodGlucose
# * HDL
# * Triglycerides
# * Income
# * Age
# * Metabolic Syndrome
#
# For the 1 Dimension below, **the means are NOT statistically different** amongst different Races: White, Asian, Black, Mexamerican, Hispanic, Other.
# * Albuminuria
#
#
# #### Limitations
# There are some limits to the conclusions.
#
# 1. Shapiro-Wilks shows that the data for all groups (residuals?) are normally distributed EXCEPT Other: WaistCirc, Other: UricAcid, Other: HDL.  The requirement for normality of residuals for ANOVA usage for all the other groupings are met.
# 2. Levenes show only Albuminuria and UricAcid groups have variances equal.  This means only these 2 groups are homoscedastic and only these two groups can be used reliably (without lots of Type I errors) in an ANOVA.
#
# References:
# * https://stats.stackexchange.com/questions/56971/alternative-to-one-way-anova-unequal-variance
#
# * https://stats.stackexchange.com/questions/91872/alternatives-to-one-way-anova-for-heteroskedastic-data/91881#91881
#
# * ChatGPT:  "It's important to note that ANOVA is robust to departures from normality when sample sizes are reasonably large. However, if your sample sizes are very small or if you suspect severe violations of the normality assumption, you might consider non-parametric alternatives like the Kruskal-Wallis test, which do not assume normality."
#
# 3. Boxplots with the 95% confidence intervals shown, show the ANOVA result ("at least one of the means is different") for WaistCirc and BMI are likely accurate (Asian is the difference) but maybe not for UrAlbCr, BloodGlucose, HDL, Triglycerides.
#
# 4. Due to limitations in time to give a deeper, more thoughtful review of the statistics rules around ANOVA, and lack of appropriate immediate toolkit for applying alternative tests that tolerate heteroscedastic data properly, further evaluation cannot be done at this time.  The results will be visualized and presented with these caveats and cautions in place.

# %% [markdown]
# # OVERALL RESULTS
#
# ### A Note About Statistical Test Application and Reliability of Conclusions
# 1. For the t-tests, the input parameters were adjusted to account for data that homoscedastic vs. hetereoscedastic.
# Therefore, the conclusions drawn from the t-tests can be regarded as sound.
# 2. For the one-way ANOVA:
# - Some conditions were violated:
#     - Homoescedasticity:  All Dimensions' data violated conditions of homoscedasticity, except for 2: the Dimensions "Albuminuria" and "UricAcid" were homoscedastic.
#     - Almost all groups of data put through ANOVA were normally distributed, with reasonably large sample sizes (all above 200, some as high as 980)
#         - Those that were not (WaistCirc for Other, UricAcid for Other, and HDL for Other) also suffered from small sample sizes (53)
#         - The Race group "Other" was entirely removed from the analysis as a "What If" scenario, but the conclusions here are drawn from the ANOVA tests where "Other" race is included.
# - The results from ANOVA are therefore more likely to suffer from Type I errors; that is, more "departure from the null hypothesis that there is no difference in group means" than accurate.
# - Limitations in statistical knowledge and time to dive deeper prevented me from running additional tests.  Therefore, the conclusions from the ANOVA will be used, with these mitigation factors:
#     - These caveats and caustions are called out.
#     - Visualizations of the means and confidence intervals will be used to help interpret the likelihood of "statistically different means"
#
#
# ### t-test Results
# 1. All of the below dimensions have different means between those that have Metabolic Syndrome and those that do not:
# * WaistCirc
# * BMI
# * Albuminuria
# * UrAlbCr
# * UricAcid
# * BloodGlucose
# * HDL
# * Triglycerides
# * Income
# * Age
#
# Barplots with Confidence Intervals shown in this notebook show these patterns:
# * Age of people with Metabolic Syndrome ("MS") is higher
# * Income of people with MS is lower
# * Triglycerides of people with MS is higher
# * HDL in people with MS is lower
# * Wait Circ, BMI, Albuminuria, UrAlbCr, UricAcid, Blood Glucose in people with MS is all higher
#
# These will be visualized in Tableau.
#
# 2. The below dimensions have different means between Males and Females (regardless of their Metabolic Syndrome status):
# * WaistCirc
# * BMI
# * UricAcid
# * BloodGlucose
# * HDL
# * Triglycerides
#
# 3. The below dimensions do **not** have different means between Males and Females:
# * Albuminuria (TODO: More research)
# * UrAlbCr (TODO: More research)
# * Income (good news! An interesting side note falling from the data)
# * Age
#
# ### ANOVA Results
# 1. Results show that in all dimensions **except** Albuminuria, at least one mean differs between Races
# 2. Due to the fact that only Albuminuria and UricAcid were the only two groupings that were homoscedastic, potentially the most conservative conclusion we can make is that:
# - "Albuminuria across Races is not different"
# - "UricAcid across Races IS different"
# 3. However, using Barplots with confidence intervals and Visualizations to help interpret the ANOVA results, we may be able to see that the following are likely to have at least one Race has a different mean, and these potential conclusions:
# * WaistCirc and BMI is lower in those from Asian Race
# * Triglycerides are lower in those from Black Race (when "Other" Race is removed)
# * Income is higher in those from Asian Race
# * Potentially that there is a lower proportion of the sample that have Metabolic Syndrome in Asian and Black population, and potentially the Other Race (however, the confidence interval for "Other" very wide)
#
# These will be visualized in Tableau.
